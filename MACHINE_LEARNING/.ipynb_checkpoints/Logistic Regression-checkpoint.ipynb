# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
#%matplotlib notebook
plt.rcParams["figure.figsize"] = (10,6)
import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
df = pd.read_csv("hearing_test.csv")

# %%
df.head()   ##Target label is test_results, binary classificatin
# Out:
#      age  physical_score  test_result
# 0 33.000          40.700            1
# 1 50.000          37.200            1
# 2 52.000          24.700            0
# 3 56.000          31.000            0
# 4 35.000          42.900            1

# %% [markdown]
# ## Explatory Data Analysis and Visualisation (EDA)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             5000 non-null   float64
#  1   physical_score  5000 non-null   float64
#  2   test_result     5000 non-null   int64
# dtypes: float64(2), int64(1)
# memory usage: 117.3 KB

# %%
df.describe().T    ## we need to test and visualise to see outliers with data
                    ## There is no standard for mean or oth values.
# Out:
#                   count   mean    std    min    25%    50%    75%    max
# age            5000.000 51.609 11.287 18.000 43.000 51.000 60.000 90.000
# physical_score 5000.000 32.760  8.170 -0.000 26.700 35.300 38.900 50.000
# test_result    5000.000  0.600  0.490  0.000  0.000  1.000  1.000  1.000

# %%
## unbalance and balance data-> datadaki featureler arası 3500 kanserli ve 200 kansetli data varsa unbalance burada bazı değişiklikler olucak
## balance data featureler arasında eşitlik olmalı 2000 tane 1 ve 300 tane 0 valulerle devam edemeyiz.

# %%
df['test_result'].value_counts() # datalar arasında dengesizlik varmı. Classification modelde unbalance mücadele edeceğiz
# Out:
# 1    3000
# 0    2000
# Name: test_result, dtype: int64

# %%
## we must decide after getting scores for saying data unbalance.

# %%
ax = sns.countplot(df['test_result'])
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() + 0.3, p.get_height() * 1.03));

# %%
sns.boxplot(x = "test_result", y = "age", data = df);

# %%
sns.boxplot(x = "test_result", y = "physical_score", data = df)
# Out:
# <Axes: xlabel='test_result', ylabel='physical_score'>

# %%
## 23 altı alıpta testten geçen yok, bunu model düz olarak geçmedi tahmin edebilir.

# %%
## eger kategorik target varsa, hue kullanılmalı datayı tanımak için

# %%
sns.scatterplot(x = "age", y = "physical_score", data = df, hue = "test_result", alpha = 0.5)
# Out:
# <Axes: xlabel='age', ylabel='physical_score'>

# %%
sns.pairplot(df, hue = "test_result");

# %%
## data'da ne kadar iç içe geçmişse clustering'de o kadar düşük performance alırız.
## ne kadar uzaklarsa o kadar kolay ayırırlar. ## ROC, Arousal test sonuçları.

# %%
sns.heatmap(df.corr(), annot = True);

# %%
 sns.scatterplot(x = "physical_score", y = "test_result", data = df);

# %% [markdown]
# ## Train | Test Split and Scaling

# %%
X = df.drop("test_result", axis = 1)
y = df["test_result"]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = 101)

# %%
scaler = StandardScaler()

# %%
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ## Modelling

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_model = LogisticRegression()

# %%
log_model.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression()

# %%
log_model.coef_   ## effect of the age adn physical score on the data.
# Out:
# array([[-0.94953524,  3.45991194]])

# %%
log_model.intercept_
# Out:
# array([0.48867341])

# %%
y_pred = log_model.predict(X_test_scaled)
y_pred;

# %%
y_pred_proba = log_model.predict_proba(X_test_scaled) # 0 ve 1 klaslarına ait olma olasılık değerlerini verir
y_pred_proba  # yukarıdaki 1 ve 0 sıfır değerleri oluşturan olasılık değeri veriyor 0 klasındaki değer > 0.5 => 0 , değilse 1 klası büyktür 1 yazar
# Out:
# array([[2.38434328e-02, 9.76156567e-01],
#        [2.69240761e-02, 9.73075924e-01],
#        [9.89194168e-01, 1.08058325e-02],
#        [1.90768955e-03, 9.98092310e-01],
#        [9.75012619e-01, 2.49873806e-02],
#        [9.89652504e-01, 1.03474957e-02],
#        [7.40226674e-02, 9.25977333e-01],
#        [1.70943342e-02, 9.82905666e-01],
#        [9.97066033e-01, 2.93396692e-03],
#        [3.30521615e-02, 9.66947839e-01],
#        [8.31035903e-02, 9.16896410e-01],
#        [9.92865306e-03, 9.90071347e-01],
#        [7.08965218e-03, 9.92910348e-01],
#        [9.34236379e-01, 6.57636209e-02],
#        [1.16594927e-04, 9.99883405e-01],
#        [6.58904151e-02, 9.34109585e-01],
#        [9.89126706e-01, 1.08732938e-02],
#        [2.80051357e-03, 9.97199486e-01],
#        [5.58920624e-04, 9.99441079e-01],
#        [9.96523291e-01, 3.47670946e-03],
#        [8.81757060e-01, 1.18242940e-01],
#        [1.31030473e-01, 8.68969527e-01],
#        [5.45646751e-01, 4.54353249e-01],
# ...

# %% [markdown]
# ## X_test + y_test + y_pred + y_pred_probm

# %%
test_data = pd.concat([X_test, y_test], axis = 1)
test_data
# Out:
#         age  physical_score  test_result
# 1718 39.000          37.800            1
# 2511 45.000          38.700            1
# 345  56.000          21.800            0
# 2521 40.000          44.000            1
# 54   64.000          25.400            0
# ...     ...             ...          ...
# 4770 46.000          37.700            1
# 188  59.000          36.500            1
# 3335 54.000          22.800            0
# 4583 58.000          20.500            0
# 3208 48.000          24.700            0
#
# [500 rows x 3 columns]

# %%
test_data["pred_prob"] = y_pred_proba[:, 1]
test_data
# Out:
#         age  physical_score  test_result  pred_prob
# 1718 39.000          37.800            1      0.976
# 2511 45.000          38.700            1      0.973
# 345  56.000          21.800            0      0.011
# 2521 40.000          44.000            1      0.998
# 54   64.000          25.400            0      0.025
# ...     ...             ...          ...        ...
# 4770 46.000          37.700            1      0.956
# 188  59.000          36.500            1      0.813
# 3335 54.000          22.800            0      0.019
# 4583 58.000          20.500            0      0.005
# 3208 48.000          24.700            0      0.069
#
# [500 rows x 4 columns]

# %%
test_data["pred"] = y_pred
test_data
# Out:
#         age  physical_score  test_result  pred_prob  pred
# 1718 39.000          37.800            1      0.976     1
# 2511 45.000          38.700            1      0.973     1
# 345  56.000          21.800            0      0.011     0
# 2521 40.000          44.000            1      0.998     1
# 54   64.000          25.400            0      0.025     0
# ...     ...             ...          ...        ...   ...
# 4770 46.000          37.700            1      0.956     1
# 188  59.000          36.500            1      0.813     1
# 3335 54.000          22.800            0      0.019     0
# 4583 58.000          20.500            0      0.005     0
# 3208 48.000          24.700            0      0.069     0
#
# [500 rows x 5 columns]

# %%
test_data.sample(10)
# Out:
#         age  physical_score  test_result  pred_prob  pred
# 3867 53.000          22.500            0      0.019     0
# 3876 42.000          31.100            0      0.649     1
# 4200 67.000          20.100            0      0.002     0
# 3297 47.000          39.000            1      0.972     1
# 105  55.000          34.500            1      0.723     1
# 353  78.000          14.800            0      0.000     0
# 2507 50.000          40.600            0      0.982     1
# 2889 45.000          28.000            0      0.278     0
# 2533 40.000          38.500            1      0.981     1
# 1842 67.000          17.500            0      0.001     0

# %%
sns.scatterplot(x = "age", y = "physical_score", data = test_data, hue = "pred", alpha = 0.5)
# Out:
# <Axes: xlabel='age', ylabel='physical_score'>

# %%
test_data.groupby("test_result").pred.value_counts()
# Out:
# test_result  pred
# 0            0       172
#              1        21
# 1            1       293
#              0        14
# Name: pred, dtype: int64

# %% [markdown]
# ## Model Performance on Classification Tasks

# %% [raw]
# accuracy
# recall
# precision
# f1_score
# confusion_matrix
# classification report)

# %%
from sklearn.metrics import precision_score, recall_score, accuracy_score, f1_score

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.93

# %%
log_model.score(X_test_scaled, y_test) # log_model içine x ve y testleri alır. accuracy_score ile aynı değerleri verir.
# Out:
# 0.93

# %%
precision_score(y_test, y_pred)
# Out:
# 0.9331210191082803

# %%
recall_score(y_test, y_pred)
# Out:
# 0.9543973941368078

# %%
f1_score(y_test, y_pred)
# Out:
# 0.9436392914653785

# %%
from sklearn.metrics import confusion_matrix, classification_report, ConfusionMatrixDisplay

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[172,  21],
#        [ 14, 293]])

# %%
ConfusionMatrixDisplay.from_estimator(log_model, X_test, y_pred)

# %% [markdown]
# ![image%20%284%29.png](attachment:image%20%284%29.png)

# %%
ConfusionMatrixDisplay(y_test)
plt.show()

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.89      0.91       193
#            1       0.93      0.95      0.94       307
#
#     accuracy                           0.93       500
#    macro avg       0.93      0.92      0.93       500
# weighted avg       0.93      0.93      0.93       500

# %%
y_train_pred = log_model.predict(X_train_scaled)
print(classification_report(y_train,y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.87      0.89      1807
#            1       0.91      0.95      0.93      2693
#
#     accuracy                           0.91      4500
#    macro avg       0.91      0.91      0.91      4500
# weighted avg       0.91      0.91      0.91      4500

# %% [markdown]
# ![Precisionrecall.svg.png](attachment:Precisionrecall.svg.png)

# %%
from sklearn.model_selection import cross_validate

# %%
import sklearn
sklearn.metrics.SCORERS.keys()
# Out:
# dict_keys(['explained_variance', 'r2', 'max_error', 'matthews_corrcoef', 'neg_median_absolute_error', 'neg_mean_absolute_error', 'neg_mean_absolute_percentage_error', 'neg_mean_squared_error', 'neg_mean_squared_log_error', 'neg_root_mean_squared_error', 'neg_mean_poisson_deviance', 'neg_mean_gamma_deviance', 'accuracy', 'top_k_accuracy', 'roc_auc', 'roc_auc_ovr', 'roc_auc_ovo', 'roc_auc_ovr_weighted', 'roc_auc_ovo_weighted', 'balanced_accuracy', 'average_precision', 'neg_log_loss', 'neg_brier_score', 'positive_likelihood_ratio', 'neg_negative_likelihood_ratio', 'adjusted_rand_score', 'rand_score', 'homogeneity_score', 'completeness_score', 'v_measure_score', 'mutual_info_score', 'adjusted_mutual_info_score', 'normalized_mutual_info_score', 'fowlkes_mallows_score', 'precision', 'precision_macro', 'precision_micro', 'precision_samples', 'precision_weighted', 'recall', 'recall_macro', 'recall_micro', 'recall_samples', 'recall_weighted', 'f1', 'f1_macro', 'f1_micro', 'f1_samples', 'f1_we
# ...

# %%
model = LogisticRegression()

scores = cross_validate(model, X_train_scaled, y_train, scoring = ["accuracy", "precision", "recall", "f1"], cv = 10)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores
# Out:
#     fit_time  score_time  test_accuracy  test_precision  test_recall  test_f1
# 1      0.010       0.013          0.900           0.889        0.952    0.919
# 2      0.013       0.017          0.924           0.921        0.956    0.938
# 3      0.013       0.011          0.936           0.917        0.981    0.948
# 4      0.011       0.010          0.931           0.938        0.948    0.943
# 5      0.008       0.010          0.938           0.941        0.955    0.948
# 6      0.009       0.010          0.902           0.934        0.900    0.917
# 7      0.010       0.009          0.898           0.889        0.948    0.917
# 8      0.009       0.009          0.911           0.896        0.963    0.928
# 9      0.009       0.009          0.891           0.910        0.907    0.909
# 10     0.008       0.011          0.916           0.911        0.952    0.931

# %%
df_scores.mean()[2:]
# Out:
# test_accuracy    0.915
# test_precision   0.915
# test_recall      0.946
# test_f1          0.930
# dtype: float64

# %%
print("Test Set")
print(classification_report(y_test,y_pred))
print("Train Set\n")
y_train_pred = log_model.predict(X_train_scaled)
print(classification_report(y_train,y_train_pred))
# Out:
# Test Set
#               precision    recall  f1-score   support
#
#            0       0.92      0.89      0.91       193
#            1       0.93      0.95      0.94       307
#
#     accuracy                           0.93       500
#    macro avg       0.93      0.92      0.93       500
# weighted avg       0.93      0.93      0.93       500
#
# Train Set
#
#               precision    recall  f1-score   support
#
#            0       0.91      0.87      0.89      1807
#            1       0.91      0.95      0.93      2693
#
#     accuracy                           0.91      4500
#    macro avg       0.91      0.91      0.91      4500
# weighted avg       0.91      0.91      0.91      4500

# %% [markdown]
# ## ROC (Receiver Operating Curve) and AUC (Area Under Curve)

# %%
from sklearn.metrics import precision_recall_curve, PrecisionRecallDisplay, RocCurveDisplay, roc_auc_score, auc, roc_curve

   
# modelin ne kadar doğru çalıştığını verir. önemli metriktir.
# dengeli datasetlerinde kullanırız

# %%
RocCurveDisplay.from_estimator(
     log_model, X_test_scaled, y_test)

plt.show()

# %%
roc_auc_score(y_test, y_pred_proba[:,1]) #olasılıklar üzerinden sonuç verdiği için 1 clasının y_test ve y_pred_proba verilir
# Out:
# 0.9630132824762451

# %%
roc_auc_score(y_test, y_pred) #olasılıklar üzerinden sonuç verdiği için 1 clasının y_test ve y_pred_proba verilir
# Out:
# 0.9227945519906837

# %% [markdown]
# ## Precision Recall Curve

# %%
## Precission Recall Curve
PrecisionRecallDisplay.from_estimator(log_model, X_test_scaled, y_test)
plt.show()

# %% [markdown]
# ## PRC and ROC AUC Trick
#
# #### ROC Curve ve Precision-Recall Curve skorlarımıza bakarak, datamızın balanced mı unbalanced mı olduğuna dair fikir sahibi olabiliriz. İki skor birbirine yakın ve aynıysa balanced, arada fark varsa unbalanced olabileceğine dair çıkarım yapabiliriz.

# %% [markdown]
# ## Final Modeel and Model Deployment

# %%
scaler = StandardScaler().fit(X)

# %%
import pickle #X datayı kaydeder
pickle.dump(scaler, open("scaler_hearing", "wb"))

# %%
X_scaled = scaler.transform(X)

# %%
final_model = LogisticRegression().fit(X_scaled, y)

# %%
pickle.dump(final_model, open("final_model_hearing", "wb"))

# %%
my_dict = {"age": [20, 30, 40, 50, 60],
           "physical_score": [50, 30, 20, 10, 5]}

# %%
sample = pd.DataFrame(my_dict)  ## modeli test etmek için dict içinde df oluşturulur.
sample
# Out:
#    age  physical_score
# 0   20              50
# 1   30              30
# 2   40              20
# 3   50              10
# 4   60               5

# %%
scaler_hearing = pickle.load(open("scaler_hearing", "rb"))

# %%
sample_scaled = scaler_hearing.transform(sample)
sample_scaled   ##
# Out:
# array([[-2.80075819,  2.11038956],
#        [-1.91469467, -0.33789511],
#        [-1.02863115, -1.56203745],
#        [-0.14256762, -2.78617979],
#        [ 0.7434959 , -3.39825096]])

# %%
finl_model = pickle.load(open("final_model_hearing", "rb"))

# %%
predictions = final_model.predict(sample_scaled) # final modele predict için scale edilen sample verilir
predictions_proba = final_model.predict_proba(sample_scaled) # samplenin proba değerlerini alırız

# %%
sample["pred"] = predictions
sample["pred_proba"] = predictions_proba[:,1]
sample
# Out:
#    age  physical_score  pred  pred_proba
# 0   20              50     1       1.000
# 1   30              30     1       0.730
# 2   40              20     0       0.016
# 3   50              10     0       0.000
# 4   60               5     0       0.000

# %% [markdown]
# ## Notebook Bitti
